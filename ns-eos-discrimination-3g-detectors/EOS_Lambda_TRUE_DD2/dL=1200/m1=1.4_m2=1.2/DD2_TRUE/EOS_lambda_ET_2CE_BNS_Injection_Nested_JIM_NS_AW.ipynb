# %%
# !pip install git+https://github.com/adil1828/GW_JAX_TEAM_Nested
# Out:
# Collecting git+https://github.com/adil1828/GW_JAX_TEAM_Nested
#   Cloning https://github.com/adil1828/GW_JAX_TEAM_Nested to /tmp/pip-req-build-rn8wvghb
#   Running command git clone --filter=blob:none --quiet https://github.com/adil1828/GW_JAX_TEAM_Nested /tmp/pip-req-build-rn8wvghb
#   Resolved https://github.com/adil1828/GW_JAX_TEAM_Nested to commit 8ae26f8ca3030cc92d9342685389714907ca7a94
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting anesthetic>=2 (from JimGW==0.0.1.dev5)
#   Downloading anesthetic-2.14.9-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: astropy>=7.0.1 in /usr/local/lib/python3.12/dist-packages (from JimGW==0.0.1.dev5) (7.2.1)
# Requirement already satisfied: beartype>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from JimGW==0.0.1.dev5) (0.22.9)
# Collecting blackjax>=1.4 (from JimGW==0.0.1.dev5)
#   Downloading blackjax-1.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting corner>=2.2.3 (from JimGW==0.0.1.dev5)
#   Downloading corner-2.3.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting equinox>=0.11 (from JimGW==0.0.1.dev5)
#   Downloading equinox-0.13.8-py3-none-any.whl.metadata (18 kB)
# Collecting evosax>=0.2.0 (from JimGW==0.0.1.dev5)
#   Downloading evosax-0.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting flowmc>=0.6.1 (from JimGW==0.0.1.dev5)
#   Downloading flowmc-0.6.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting gwpy>=3.0.12 (from JimGW==0.0.1.dev5)
#   Downloading gwpy-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting jax>=0.8.2 (from JimGW==0.0.1.dev5)
#   Downloading jax-0.10.2-py3-none-any.whl.metadata (13 kB)
# Collecting jaxtyping>=0.3.3 (from JimGW==0.0.1.dev5)
#   Downloading jaxtyping-0.3.11-py3-none-any.whl.metadata (6.2 kB)
# Collecting matplotlib>=3.10.7 (from JimGW==0.0.1.dev5)
#   Downloading matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from JimGW==0.0.1.dev5) (2.0.2)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.12/dist-packages (from JimGW==0.0.1.dev5) (2.13.4)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from JimGW==0.0.1.dev5) (2.32.4)
# Collecting ripplegw>=0.2.1 (from JimGW==0.0.1.dev5)
#   Downloading ripplegw-0.2.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting scipy>=1.17.1 (from JimGW==0.0.1.dev5)
#   Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 7.2 MB/s eta 0:00:00
# Collecting tomli-w>=1.0 (from JimGW==0.0.1.dev5)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typer>=0.12 in /usr/local/lib/python3.12/dist-packages (from JimGW==0.0.1.dev5) (0.25.1)
# Requirement already satisfied: pandas<3.1.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from anesthetic>=2->JimGW==0.0.1.dev5) (2.2.2)
# Requirement already satisfied: astropy-iers-data>=0.2026.6.1.17.39.59 in /usr/local/lib/python3.12/dist-packages (from astropy>=7.0.1->JimGW==0.0.1.dev5) (0.2026.6.22.1.23.34)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=7.0.1->JimGW==0.0.1.dev5) (26.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from astropy>=7.0.1->JimGW==0.0.1.dev5) (2.0.1.5)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=7.0.1->JimGW==0.0.1.dev5) (6.0.3)
# Collecting jaxlib>=0.9.0 (from blackjax>=1.4->JimGW==0.0.1.dev5)
#   Downloading jaxlib-0.10.2-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: optax>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from blackjax>=1.4->JimGW==0.0.1.dev5) (0.2.8)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from blackjax>=1.4->JimGW==0.0.1.dev5) (4.15.0)
# Collecting wadler-lindig>=0.1.0 (from equinox>=0.11->JimGW==0.0.1.dev5)
#   Downloading wadler_lindig-0.1.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: flax>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from evosax>=0.2.0->JimGW==0.0.1.dev5) (0.11.2)
# Collecting dotmap (from evosax>=0.2.0->JimGW==0.0.1.dev5)
#   Downloading dotmap-1.3.30-py3-none-any.whl.metadata (3.2 kB)
# Collecting diffrax>=0.7.0 (from flowmc>=0.6.1->JimGW==0.0.1.dev5)
#   Downloading diffrax-0.7.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from flowmc>=0.6.1->JimGW==0.0.1.dev5) (4.67.3)
# Collecting dateparser>=1.2.0 (from gwpy>=3.0.12->JimGW==0.0.1.dev5)
#   Downloading dateparser-1.4.1-py3-none-any.whl.metadata (22 kB)
# Collecting dqsegdb2>=1.3.0 (from gwpy>=3.0.12->JimGW==0.0.1.dev5)
#   Downloading dqsegdb2-1.3.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting gwdatafind>=2.0.0 (from gwpy>=3.0.12->JimGW==0.0.1.dev5)
#   Downloading gwdatafind-2.1.1-py3-none-any.whl.metadata (3.6 kB)
# Collecting gwosc>=0.6.0 (from gwpy>=3.0.12->JimGW==0.0.1.dev5)
#   Downloading gwosc-0.8.3-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from gwpy>=3.0.12->JimGW==0.0.1.dev5) (3.16.0)
# Collecting igwn-segments>=2.0.0 (from gwpy>=3.0.12->JimGW==0.0.1.dev5)
#   Downloading igwn_segments-2.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (2.0 kB)
# Collecting ligotimegps>=2.1.0 (from gwpy>=3.0.12->JimGW==0.0.1.dev5)
#   Downloading ligotimegps-2.1.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: python-dateutil>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from gwpy>=3.0.12->JimGW==0.0.1.dev5) (2.9.0.post0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.8.2->JimGW==0.0.1.dev5) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.8.2->JimGW==0.0.1.dev5) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.7->JimGW==0.0.1.dev5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.7->JimGW==0.0.1.dev5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.7->JimGW==0.0.1.dev5) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.7->JimGW==0.0.1.dev5) (1.5.0)
# Requirement already satisfied: pillow>=9 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.7->JimGW==0.0.1.dev5) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.7->JimGW==0.0.1.dev5) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->JimGW==0.0.1.dev5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->JimGW==0.0.1.dev5) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->JimGW==0.0.1.dev5) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->JimGW==0.0.1.dev5) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->JimGW==0.0.1.dev5) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->JimGW==0.0.1.dev5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->JimGW==0.0.1.dev5) (2026.6.17)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12->JimGW==0.0.1.dev5) (8.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12->JimGW==0.0.1.dev5) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12->JimGW==0.0.1.dev5) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.12->JimGW==0.0.1.dev5) (0.0.4)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.12/dist-packages (from dateparser>=1.2.0->gwpy>=3.0.12->JimGW==0.0.1.dev5) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser>=1.2.0->gwpy>=3.0.12->JimGW==0.0.1.dev5) (2025.11.3)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser>=1.2.0->gwpy>=3.0.12->JimGW==0.0.1.dev5) (5.4.3)
# Collecting lineax>=0.0.5 (from diffrax>=0.7.0->flowmc>=0.6.1->JimGW==0.0.1.dev5)
#   Downloading lineax-0.1.1-py3-none-any.whl.metadata (17 kB)
# Collecting optimistix>=0.1.0 (from diffrax>=0.7.0->flowmc>=0.6.1->JimGW==0.0.1.dev5)
#   Downloading optimistix-0.1.0-py3-none-any.whl.metadata (18 kB)
# Collecting igwn-auth-utils>=1.0.0 (from dqsegdb2>=1.3.0->gwpy>=3.0.12->JimGW==0.0.1.dev5)
#   Downloading igwn_auth_utils-1.4.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (1.2.1)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (0.12.0)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (0.1.84)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (0.1.10)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from gwosc>=0.6.0->gwpy>=3.0.12->JimGW==0.0.1.dev5) (9.1.4)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from optax>=0.2.3->blackjax>=1.4->JimGW==0.0.1.dev5) (1.4.0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.1.0,>=2.2.0->anesthetic>=2->JimGW==0.0.1.dev5) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.9.0->gwpy>=3.0.12->JimGW==0.0.1.dev5) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer>=0.12->JimGW==0.0.1.dev5) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer>=0.12->JimGW==0.0.1.dev5) (2.20.0)
# Requirement already satisfied: cryptography>=44.0.1 in /usr/local/lib/python3.12/dist-packages (from igwn-auth-utils>=1.0.0->dqsegdb2>=1.3.0->gwpy>=3.0.12->JimGW==0.0.1.dev5) (49.0.0)
# Collecting safe-netrc>=1.0 (from igwn-auth-utils>=1.0.0->dqsegdb2>=1.3.0->gwpy>=3.0.12->JimGW==0.0.1.dev5)
#   Downloading safe_netrc-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting scitokens>=1.8 (from igwn-auth-utils>=1.0.0->dqsegdb2>=1.3.0->gwpy>=3.0.12->JimGW==0.0.1.dev5)
#   Downloading scitokens-1.9.7-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.12->JimGW==0.0.1.dev5) (0.1.2)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (1.14.0)
# Requirement already satisfied: prometheus-client>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (0.25.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (25.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (5.29.6)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (4.15.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (4.1.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (5.9.5)
# Requirement already satisfied: uvloop in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (0.22.1)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=44.0.1->igwn-auth-utils>=1.0.0->dqsegdb2>=1.3.0->gwpy>=3.0.12->JimGW==0.0.1.dev5) (2.0.0)
# Requirement already satisfied: PyJWT>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from scitokens>=1.8->igwn-auth-utils>=1.0.0->dqsegdb2>=1.3.0->gwpy>=3.0.12->JimGW==0.0.1.dev5) (2.13.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (2025.3.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.10.0->evosax>=0.2.0->JimGW==0.0.1.dev5) (4.1.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=44.0.1->igwn-auth-utils>=1.0.0->dqsegdb2>=1.3.0->gwpy>=3.0.12->JimGW==0.0.1.dev5) (3.0)
# Downloading anesthetic-2.14.9-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 11.4 MB/s eta 0:00:00
# Downloading blackjax-1.6-py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 106.3 MB/s eta 0:00:00
# Downloading corner-2.3.0-py3-none-any.whl (16 kB)
# Downloading equinox-0.13.8-py3-none-any.whl (185 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 22.5 MB/s eta 0:00:00
# Downloading evosax-0.2.0-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.0/214.0 kB 27.0 MB/s eta 0:00:00
# Downloading flowmc-0.6.1-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 12.6 MB/s eta 0:00:00
# Downloading gwpy-4.0.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 99.6 MB/s eta 0:00:00
# Downloading jax-0.10.2-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 133.7 MB/s eta 0:00:00
# Downloading jaxtyping-0.3.11-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 7.0 MB/s eta 0:00:00
# Downloading matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 155.6 MB/s eta 0:00:00
# Downloading ripplegw-0.2.1-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.6/184.6 kB 23.0 MB/s eta 0:00:00
# Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 71.4 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading dateparser-1.4.1-py3-none-any.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.5/300.5 kB 33.3 MB/s eta 0:00:00
# Downloading diffrax-0.7.2-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 kB 23.9 MB/s eta 0:00:00
# Downloading dqsegdb2-1.3.0-py3-none-any.whl (27 kB)
# Downloading gwdatafind-2.1.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 5.6 MB/s eta 0:00:00
# Downloading gwosc-0.8.3-py3-none-any.whl (36 kB)
# Downloading igwn_segments-2.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.0/115.0 kB 14.4 MB/s eta 0:00:00
# Downloading jaxlib-0.10.2-cp312-cp312-manylinux_2_27_x86_64.whl (85.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 28.7 MB/s eta 0:00:00
# Downloading ligotimegps-2.1.0-py3-none-any.whl (23 kB)
# Downloading wadler_lindig-0.1.7-py3-none-any.whl (20 kB)
# Downloading dotmap-1.3.30-py3-none-any.whl (11 kB)
# Downloading igwn_auth_utils-1.4.0-py3-none-any.whl (34 kB)
# Downloading lineax-0.1.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 10.4 MB/s eta 0:00:00
# Downloading optimistix-0.1.0-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 13.9 MB/s eta 0:00:00
# Downloading safe_netrc-1.0.1-py3-none-any.whl (10 kB)
# Downloading scitokens-1.9.7-py3-none-any.whl (34 kB)
# Building wheels for collected packages: JimGW
#   Building wheel for JimGW (pyproject.toml) ... done
#   Created wheel for JimGW: filename=jimgw-0.0.1.dev5-py3-none-any.whl size=127734 sha256=b8d67d5229d6dafe8000f91091df09ab5b9ece95b2814cf3be19d500abe4bc69
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uw7in0je/wheels/f8/b4/da/98676d28d556c41ee24e012692bff35d3cf6caf0604b58d3da
# Successfully built JimGW
# Installing collected packages: dotmap, wadler-lindig, tomli-w, scipy, safe-netrc, ligotimegps, igwn-segments, matplotlib, jaxtyping, jaxlib, gwosc, dateparser, scitokens, jax, corner, anesthetic, ripplegw, igwn-auth-utils, equinox, lineax, gwdatafind, dqsegdb2, blackjax, optimistix, gwpy, evosax, diffrax, flowmc, JimGW
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.7.2
#     Uninstalling jaxlib-0.7.2:
#       Successfully uninstalled jaxlib-0.7.2
#   Attempting uninstall: jax
#     Found existing installation: jax 0.7.2
#     Uninstalling jax-0.7.2:
#       Successfully uninstalled jax-0.7.2
# Successfully installed JimGW-0.0.1.dev5 anesthetic-2.14.9 blackjax-1.6 corner-2.3.0 dateparser-1.4.1 diffrax-0.7.2 dotmap-1.3.30 dqsegdb2-1.3.0 equinox-0.13.8 evosax-0.2.0 flowmc-0.6.1 gwdatafind-2.1.1 gwosc-0.8.3 gwpy-4.0.1 igwn-auth-utils-1.4.0 igwn-segments-2.1.1 jax-0.10.2 jaxlib-0.10.2 jaxtyping-0.3.11 ligotimegps-2.1.0 lineax-0.1.1 matplotlib-3.11.0 optimistix-0.1.0 ripplegw-0.2.1 safe-netrc-1.0.1 scipy-1.18.0 scitokens-1.9.7 tomli-w-1.2.0 wadler-lindig-0.1.7

# %%
import time
#from pathlib import Path

# %%
"""GW150914 analysis with the BlackJAX NS-AW nested sampler."""
# Out:
# 'GW150914 analysis with the BlackJAX NS-AW nested sampler.'

# %%
import corner
import numpy as np
import jax
import jax.numpy as jnp
# Out:
# /usr/local/lib/python3.12/dist-packages/jaxlib/plugin_support.py:91: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.7.2 is installed, but it is not compatible with the installed jaxlib version 0.10.2, so it will not be used.
#   warnings.warn(

# %%
jax.config.update("jax_enable_x64", True)

# %%
# !pip install --upgrade "jax[cuda]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Requirement already satisfied: jax[cuda] in /usr/local/lib/python3.12/dist-packages (0.10.2)
# Requirement already satisfied: jaxlib<=0.10.2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from jax[cuda]) (0.10.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax[cuda]) (0.5.4)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from jax[cuda]) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax[cuda]) (3.4.0)
# Requirement already satisfied: scipy>=1.14 in /usr/local/lib/python3.12/dist-packages (from jax[cuda]) (1.18.0)
# Collecting jax-cuda12-plugin<=0.10.2,>=0.10.2 (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda])
#   Downloading jax_cuda12_plugin-0.10.2-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (2.0 kB)
# Collecting jax-cuda12-pjrt==0.10.2 (from jax-cuda12-plugin<=0.10.2,>=0.10.2->jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda])
#   Downloading jax_cuda12_pjrt-0.10.2-py3-none-manylinux_2_27_x86_64.whl.metadata (580 bytes)
# Requirement already satisfied: nvidia-cublas-cu12>=12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12>=12.1.105 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12>=12.6.85 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12>=12.1.105 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.8 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (9.19.0.56)
# Requirement already satisfied: nvidia-cufft-cu12>=11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (11.3.3.83)
# Requirement already satisfied: nvidia-cusolver-cu12>=11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12>=12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (12.5.8.93)
# Requirement already satisfied: nvidia-nccl-cu12>=2.18.1 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (2.28.9)
# Requirement already satisfied: nvidia-nvjitlink-cu12>=12.1.105 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12>=12.1.55 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (12.8.93)
# Requirement already satisfied: nvidia-nvshmem-cu12>=3.2.5 in /usr/local/lib/python3.12/dist-packages (from jax-cuda12-plugin[with-cuda]<=0.10.2,>=0.10.2; extra == "cuda"->jax[cuda]) (3.4.5)
# Downloading jax_cuda12_plugin-0.10.2-cp312-cp312-manylinux_2_27_x86_64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 104.6 MB/s eta 0:00:00
# Downloading jax_cuda12_pjrt-0.10.2-py3-none-manylinux_2_27_x86_64.whl (174.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.4/174.4 MB 12.9 MB/s eta 0:00:00
# Installing collected packages: jax-cuda12-pjrt, jax-cuda12-plugin
#   Attempting uninstall: jax-cuda12-pjrt
#     Found existing installation: jax-cuda12-pjrt 0.7.2
#     Uninstalling jax-cuda12-pjrt-0.7.2:
#       Successfully uninstalled jax-cuda12-pjrt-0.7.2
#   Attempting uninstall: jax-cuda12-plugin
#     Found existing installation: jax-cuda12-plugin 0.7.2
#     Uninstalling jax-cuda12-plugin-0.7.2:
#       Successfully uninstalled jax-cuda12-plugin-0.7.2
# Successfully installed jax-cuda12-pjrt-0.10.2 jax-cuda12-plugin-0.10.2

# %%
from jimgw.core.jim import Jim
from jimgw.core.prior import (
    CombinePrior,
    UniformPrior,
    CosinePrior,
    SinePrior,
    PowerLawPrior,
)
from jimgw.core.prior import GaussianPrior, StandardNormalDistribution
from jimgw.core.single_event.detector import get_ET, get_CE
from jimgw.core.single_event.likelihood import TransientLikelihoodFD,HeterodynedTransientLikelihoodFD
from jimgw.core.single_event.data import Data
from jimgw.core.single_event.waveform import RippleIMRPhenomXAS,RippleIMRPhenomXPHM,RippleIMRPhenomD,RippleIMRPhenomD_NRTidalv2


from jimgw.core.single_event.transforms import (
    MassRatioToSymmetricMassRatioTransform,
    GeocentricArrivalTimeToDetectorArrivalTimeTransform,
    SkyFrameToDetectorFrameSkyPositionTransform,
)
from jimgw.core.transforms import (
    BoundToBound,
    CosineTransform,
    PowerLawTransform,
    reverse_bijective_transform,
)
from jimgw.samplers.config import BlackJAXNSAWConfig
# Out:
# ERROR:jax._src.xla_bridge:Jax plugin configuration error: Exception when calling jax_plugins.xla_cuda12.initialize()
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/jax/_src/xla_bridge.py", line 508, in discover_pjrt_plugins
#     plugin_module.initialize()
#   File "/usr/local/lib/python3.12/dist-packages/jax_plugins/xla_cuda12/__init__.py", line 381, in initialize
#     cuda_plugin_extension.register_custom_type, c_api
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'jax_cuda12_plugin.cuda_plugin_extension' has no attribute 'register_custom_type'. Did you mean: 'register_custom_type_id'?

# %%
import jimgw
import inspect

print("jimgw version :", jimgw.__version__)
print("jimgw location:", inspect.getfile(jimgw))
# Out:
# jimgw version : 0.0.1.dev5
# jimgw location: /usr/local/lib/python3.12/dist-packages/jimgw/__init__.py

# %%
import blackjax
import inspect

print("blackjax version :", blackjax.__version__)
print("blackjax location:", inspect.getfile(blackjax))
# Out:
# blackjax version : 1.6
# blackjax location: /usr/local/lib/python3.12/dist-packages/blackjax/__init__.py

# %%
import anesthetic
import inspect

print("anesthetic version :", anesthetic.__version__)
print("anesthetic location:", inspect.getfile(anesthetic))
# Out:
# anesthetic version : 2.14.9
# anesthetic location: /usr/local/lib/python3.12/dist-packages/anesthetic/__init__.py

# %%
import sys, pkg_resources

packages = [
    "jax", "jaxlib",
    "jax-cuda12-plugin", "jax-cuda12-pjrt",
    "blackjax", "anesthetic", "jimgw",
    "numpy", "scipy"
]

for p in packages:
    try:
        dist = pkg_resources.get_distribution(p)
        print(f"{p}=={dist.version}")
    except Exception:
        print(f"{p}: NOT INSTALLED")
# Out:
# jax==0.10.2
# jaxlib==0.10.2
# jax-cuda12-plugin==0.10.2
# jax-cuda12-pjrt==0.10.2
# blackjax==1.6
# anesthetic==2.14.9
# jimgw==0.0.1.dev5
# numpy==2.0.2
# scipy==1.18.0
# /tmp/ipykernel_2032/4177245185.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import sys, pkg_resources

# %%
# !pip uninstall -y blackjax
# !pip install -U "blackjax @ git+https://github.com/blackjax-devs/blackjax.git"
# Out:
# Found existing installation: blackjax 1.6
# Uninstalling blackjax-1.6:
#   Successfully uninstalled blackjax-1.6
# Collecting blackjax@ git+https://github.com/blackjax-devs/blackjax.git
#   Cloning https://github.com/blackjax-devs/blackjax.git to /tmp/pip-install-w9j6w8km/blackjax_19640e838bf04cc886cef1e982476676
#   Running command git clone --filter=blob:none --quiet https://github.com/blackjax-devs/blackjax.git /tmp/pip-install-w9j6w8km/blackjax_19640e838bf04cc886cef1e982476676
#   Resolved https://github.com/blackjax-devs/blackjax.git to commit 0df2fe07f6773f52191701879593a40b03c27a47
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jax>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from blackjax@ git+https://github.com/blackjax-devs/blackjax.git) (0.10.2)
# Requirement already satisfied: jaxlib>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from blackjax@ git+https://github.com/blackjax-devs/blackjax.git) (0.10.2)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from blackjax@ git+https://github.com/blackjax-devs/blackjax.git) (2.0.2)
# Requirement already satisfied: optax>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from blackjax@ git+https://github.com/blackjax-devs/blackjax.git) (0.2.8)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from blackjax@ git+https://github.com/blackjax-devs/blackjax.git) (1.18.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from blackjax@ git+https://github.com/blackjax-devs/blackjax.git) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.9.0->blackjax@ git+https://github.com/blackjax-devs/blackjax.git) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.9.0->blackjax@ git+https://github.com/blackjax-devs/blackjax.git) (3.4.0)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from optax>=0.2.3->blackjax@ git+https://github.com/blackjax-devs/blackjax.git) (1.4.0)
# Building wheels for collected packages: blackjax
#   Building wheel for blackjax (pyproject.toml) ... done
#   Created wheel for blackjax: filename=blackjax-1.7.dev15+g0df2fe07f-py3-none-any.whl size=4903041 sha256=b0e10148a6276d1ab415938934648045449fd0e2e6f1d7e39d65330aa573ca2e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bm84kf0p/wheels/bc/8f/c3/b14be13ef107ea18dd389d9bd1745278ceee5a6768d4c8317d
# Successfully built blackjax
# Installing collected packages: blackjax
# Successfully installed blackjax-1.7.dev15+g0df2fe07f

# %%
import jax, jaxlib, blackjax
print("jax", jax.__version__)
print("jaxlib", jaxlib.__version__)
print("blackjax", blackjax.__version__)
print(jax.devices())
# Out:
# jax 0.10.2
# jaxlib 0.10.2
# blackjax 1.6
# [CudaDevice(id=0)]

# %%
import blackjax

print(blackjax.__version__)
print(hasattr(blackjax, "ns"))
# Out:
# 1.6
# True

# %%
from jimgw.core.single_event.detector import GroundBased2G
from jimgw.core.constants import DEG_TO_RAD

def get_CE2() -> GroundBased2G:
    """Second Cosmic Explorer facility, at the LIGO Livingston site geometry
    (verified against get_L1() in detector.py) -- the standard placeholder
    convention (one CE per existing LIGO site) used in CE forecasting studies."""
    return GroundBased2G(
        "CE2",
        latitude=(30 + 33.0 / 60 + 46.4196 / 3600) * DEG_TO_RAD,
        longitude=-(90 + 46.0 / 60 + 27.2654 / 3600) * DEG_TO_RAD,
        xarm_azimuth=197.7165 * DEG_TO_RAD,
        yarm_azimuth=287.7165 * DEG_TO_RAD,
        xarm_tilt=-3.121e-4,
        yarm_tilt=-6.107e-4,
        elevation=-6.574,
        modes="pc",
    )

# %%
# q_inj = 0.8
# eta_inj = q_inj / (1.0 + q_inj)**2

inj_params = {
    "M_c": 1.1276930385,
    "eta": 0.2485207101,

    "s1_z": 0.028327,
    "s2_z": 0.013249,

    "d_L": 1200.0,
   "lambda_1": 683.0949524004478,   # m1 = 1.54
   "lambda_2":  1594.4573505273822,   # m2 = 1.232
    "t_c": -2.36e-4,
    "phase_c": 2.0,

    "iota": 2.8495,
    "psi": 0.70,

   "ra": 3.4396,
    "dec": -0.3998,
}

# %%
# Injection GPS time; choose arbitrary fixed time
gps = 1187008882.43

# M_c ~ 1.2 Msun needs ~160s in-band from fmin=20Hz -- too long for a fast NS
# check. Raising fmin to 40Hz shortens the chirp to ~25.6s, which fits inside
# a 32s window (duration - post_trigger_duration = 30s available), giving
# ~15% margin so the injected data stays self-consistent with the window.
duration = 8192.0
post_trigger_duration = 2.0
start = gps + post_trigger_duration - duration
end = start + duration

psd_duration = 2048.0
psd_start = start - psd_duration
psd_end = start

fmin = 5.0
fmax = 2048.0

ifos = [get_CE(), get_CE2()] + get_ET()

# %%
waveform = RippleIMRPhenomD_NRTidalv2(f_ref=fmin, use_lambda_tildes=False)
sampling_frequency = 2*fmax

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("18213_ET20kmcolumns.txt")

plt.figure(figsize=(8,6))
plt.loglog(data[:,0], data[:,-1])

plt.xlabel("Frequency [Hz]")
plt.ylabel("PSD")
plt.grid(True, which="both")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("18213_ET20kmcolumns.txt")

freq = data[:,0]
psd  = data[:,-1]      # last column
asd  = np.sqrt(psd)

plt.figure(figsize=(8,6))
plt.loglog(freq, asd)

plt.xlabel("Frequency [Hz]")
plt.ylabel(r"ASD [$1/\sqrt{\mathrm{Hz}}$]")
plt.title("ET 20 km ASD")
plt.grid(True, which="both", ls=":")
plt.show()

# %%
import numpy as np

data = np.loadtxt("18213_ET20kmcolumns.txt")

freq = data[:,0]
psd  = data[:,3]

asd = np.sqrt(psd)

np.savetxt(
    "ET20km_ASD.txt",
    np.column_stack([freq, asd])
)

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("CE40km_ASD.txt")

plt.figure(figsize=(8,6))
plt.loglog(data[:,0], data[:,-1])

plt.xlabel("Frequency [Hz]")
plt.ylabel(r"ASD [$1/\sqrt{\mathrm{Hz}}$]")
plt.grid(True, which="both")
plt.show()

# %%
CE_NAMES = {"CE", "CE2"}   # confirm CE2's .name matches whatever your get_CE2() sets it to
ET_NAMES = {"ET1", "ET2", "ET3"}

for ifo in ifos:
    if ifo.name in CE_NAMES:
        asd_file = "CE40km_ASD.txt"       # whichever CE curve you've been using
    elif ifo.name in ET_NAMES:
        asd_file = "ET20km_ASD.txt"       # the ET curve from this session
    else:
        raise ValueError(f"no ASD mapped for {ifo.name}")
    ifo.load_and_set_psd(asd_file=asd_file)
    ifo.inject_signal(
        duration, sampling_frequency, trigger_time=gps,
        waveform_model=waveform, parameters=inj_params,
        f_min=fmin, f_max=fmax, zero_noise=True,
    )
# Out:
# INFO | jimgw.core.single_event.detector | start_time not provided. Defaulting to trigger_time - duration + 2.0 = 1187000692.430 s.
# INFO | jimgw.core.single_event.data | Computing FFT of CE_empty data
# INFO | jimgw.core.single_event.detector | For detector CE, the injected signal has:
# INFO | jimgw.core.single_event.detector |   - Optimal SNR: 79.3960
# INFO | jimgw.core.single_event.detector |   - Match filtered SNR: 79.3960+0.0000j
# INFO | jimgw.core.single_event.detector | start_time not provided. Defaulting to trigger_time - duration + 2.0 = 1187000692.430 s.
# INFO | jimgw.core.single_event.data | Computing FFT of CE2_empty data
# INFO | jimgw.core.single_event.detector | For detector CE2, the injected signal has:
# INFO | jimgw.core.single_event.detector |   - Optimal SNR: 66.9815
# INFO | jimgw.core.single_event.detector |   - Match filtered SNR: 66.9815+0.0000j
# INFO | jimgw.core.single_event.detector | start_time not provided. Defaulting to trigger_time - duration + 2.0 = 1187000692.430 s.
# INFO | jimgw.core.single_event.data | Computing FFT of ET1_empty data
# INFO | jimgw.core.single_event.detector | For detector ET1, the injected signal has:
# INFO | jimgw.core.single_event.detector |   - Optimal SNR: 22.0727
# INFO | jimgw.core.single_event.detector |   - Match filtered SNR: 22.0727+0.0000j
# INFO | jimgw.core.single_event.detector | start_time not provided. Defaulting to trigger_time - duration + 2.0 = 1187000692.430 s.
# INFO | jimgw.core.single_event.data | Computing FFT of ET2_empty data
# INFO | jimgw.core.single_event.detector | For detector ET2, the injected signal has:
# INFO | jimgw.core.single_event.detector |   - Optimal SNR: 29.1624
# INFO | jimgw.core.single_event.detector |   - Match filtered SNR: 29.1624+0.0000j
# INFO | jimgw.core.single_event.detector | start_time not provided. Defaulting to trigger_time - duration + 2.0 = 1187000692.430 s.
# INFO | jimgw.core.single_event.data | Computing FFT of ET3_empty data
# INFO | jimgw.core.single_event.detector | For detector ET3, the injected signal has:
# INFO | jimgw.core.single_event.detector |   - Optimal SNR: 18.8904
# INFO | jimgw.core.single_event.detector |   - Match filtered SNR: 18.8904+0.0000j

# %%
# for ifo in ifos:
#     ifo.load_and_set_psd(asd_file="ET20km_ASD.txt")
#     ifo.inject_signal(
#         duration,
#         sampling_frequency,
#         trigger_time=gps,
#         waveform_model=waveform,
#         parameters=inj_params,
#         f_min=fmin,
#         f_max=fmax,
#         zero_noise=True,
#     )

# %%
# import inspect
# print(inspect.signature(ifos[0].load_and_set_psd))
# print(inspect.getsource(type(ifos[0]).load_and_set_psd))

# %%
for ifo in ifos:
    print("\n", ifo.name)
    print(dir(ifo.data))
# Out:
#  CE
# ['__abstractmethods__', '__annotations__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_from_gwf', 'delta_t', 'duration', 'fd', 'fft', 'frequencies', 'frequency_slice', 'from_fd', 'from_file', 'from_gwosc', 'has_fd', 'is_empty', 'n_freq', 'n_time', 'name', 'sampling_frequency', 'set_tukey_window', 'start_time', 'td', 'times', 'to_file', 'to_psd', 'window']
#
#  CE2
# ['__abstractmethods__', '__annotations__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_from_gwf', 'delta_t', 'duration', 'fd', 'fft', 'frequencies', 'frequency_slice', 'from_fd', 'from_file', 'from_gwosc', 'has_fd', 'is_empty', 'n_freq', 'n_time', 'name', 'sampling_frequency', 'set_tukey_window', 'start_time', 'td', 'times', 'to_file', 'to_psd', 'window']
#
#  ET1
# ['__abstractmethods__', '__annotations__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_from_gwf', 'delta_t', 'duration', 'fd', 'fft', 'frequencies', 'frequency_slice', 'from_fd', 'from_file', 'from_gwosc', 'has_fd', 'is_empty', 'n_freq', 'n_time', 'name', 'sampling_frequency', 'set_tukey_window', 'start_time', 'td', 'times', 'to_file', 'to_psd', 'window']
#
#  ET2
# ['__abstractmethods__', '__annotations__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_from_gwf', 'delta_t', 'duration', 'fd', 'fft', 'frequencies', 'frequency_slice', 'from_fd', 'from_file', 'from_gwosc', 'has_fd', 'is_empty', 'n_freq', 'n_time', 'name', 'sampling_frequency', 'set_tukey_window', 'start_time', 'td', 'times', 'to_file', 'to_psd', 'window']
#
#  ET3
# ['__abstractmethods__', '__annotations__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_from_gwf', 'delta_t', 'duration', 'fd', 'fft', 'frequencies', 'frequency_slice', 'from_fd', 'from_file', 'from_gwosc', 'has_fd', 'is_empty', 'n_freq', 'n_time', 'name', 'sampling_frequency', 'set_tukey_window', 'start_time', 'td', 'times', 'to_file', 'to_psd', 'window']

# %%
import matplotlib.pyplot as plt
for ifo in ifos:
    plt.figure(figsize=(8, 4))
    plt.loglog(ifo.data.frequencies, np.abs(ifo.data.fd))
    plt.title(f"{ifo.name} frequency-domain strain")
    plt.xlabel("Frequency [Hz]")
    plt.ylabel(r"$|\tilde{d}(f)|$")
    plt.grid()
    plt.show()

# %% [markdown]
# --- Waveform model ---

# %% [markdown]
# --- Prior ---

# %%
M_c_min, M_c_max = 1.11, 1.14
q_min, q_max = 0.5, 1.0

#d_L_min, d_L_max = 30.0, 50.0
#t_det_min, t_det_max = -0.001, 0.001
t_c_min, t_c_max = -0.001, 0.001

s1_z_min, s1_z_max = -0.05, 0.05
s2_z_min, s2_z_max = -0.05, 0.05

#dL_mu, dL_sigma = 42.0, 3.0      # adjust to your intended constraint width
iota_mu, iota_sigma = 2.8495, 0.03   # see note on sigma below
d_L_min, d_L_max=400.0,2500.0

prior = CombinePrior(
    [
        UniformPrior(M_c_min, M_c_max, parameter_names=["M_c"]),
        UniformPrior(q_min, q_max, parameter_names=["q"]),

        UniformPrior(s1_z_min, s1_z_max, parameter_names=["s1_z"]),
        UniformPrior(s2_z_min, s2_z_max, parameter_names=["s2_z"]),

        #SinePrior(parameter_names=["iota"]),
         PowerLawPrior(d_L_min, d_L_max, 2.0, parameter_names=["d_L"]),
        #GaussianPrior(dL_mu, dL_sigma, parameter_names=["d_L"]),
        GaussianPrior(iota_mu, iota_sigma, parameter_names=["iota"]),
         #UniformPrior(t_det_min, t_det_max, parameter_names=["t_det"]),
        UniformPrior(t_c_min, t_c_max, parameter_names=["t_c"]),
        UniformPrior(0.0, jnp.pi, parameter_names=["psi"]),
        # UniformPrior(0.0, 2 * jnp.pi, parameter_names=["ra"]),
        # CosinePrior(parameter_names=["dec"]),

        UniformPrior(0.0, 2 * jnp.pi, parameter_names=["phase_c"]),
    ]
)

# %%
prior
# Out:
# Combine(priors=(UniformPrior(xmin=1.11, xmax=1.14, parameter_names=('M_c',)), UniformPrior(xmin=0.5, xmax=1.0, parameter_names=('q',)), UniformPrior(xmin=-0.05, xmax=0.05, parameter_names=('s1_z',)), UniformPrior(xmin=-0.05, xmax=0.05, parameter_names=('s2_z',)), PowerLawPrior(xmin=400.0, xmax=2500.0, alpha=2.0, naming=('d_L',)), GaussianPrior(mu=2.8495, sigma=0.03, parameter_names=('iota',)), UniformPrior(xmin=-0.001, xmax=0.001, parameter_names=('t_c',)), UniformPrior(xmin=0.0, xmax=3.141592653589793, parameter_names=('psi',)), UniformPrior(xmin=0.0, xmax=6.283185307179586, parameter_names=('phase_c',))), parameter_names=('M_c', 'q', 's1_z', 's2_z', 'd_L', 'iota', 't_c', 'psi', 'phase_c'))

# %%
# !pip install --upgrade equinox

# %%
import jax.numpy as jnp
from jimgw.core.transforms import BijectiveTransform
from jax.scipy.special import erf, erfinv

def norm_cdf(z):
    return 0.5 * (1 + erf(z / jnp.sqrt(2)))

def norm_ppf(p):
    return jnp.sqrt(2) * erfinv(2 * p - 1)

class GaussianQuantileTransform(BijectiveTransform):
    """Natural direction: unit cube -> Gaussian(mu, sigma), same convention as PowerLawTransform."""
    def __init__(self, name_mapping, mu, sigma):
        super().__init__(name_mapping)
        self.mu = mu
        self.sigma = sigma
        self.transform_func = self._forward
        self.inverse_transform_func = self._inverse

    def _forward(self, params):
        # unit-cube -> physical
        u = params[self.name_mapping[0][0]]
        x = self.mu + self.sigma * norm_ppf(u)
        return {self.name_mapping[1][0]: x}

    def _inverse(self, params):
        # physical -> unit-cube
        x = params[self.name_mapping[1][0]]
        u = norm_cdf((x - self.mu) / self.sigma)
        return {self.name_mapping[0][0]: u}

# %% [markdown]
# --- Transforms ---
#
# Each parameter is mapped to [0, 1].  Transform patterns:
#   Uniform [a, b]           → BoundToBound([a, b] → [0, 1])
#   SinePrior  [0, π]        → CosineTransform → BoundToBound([-1, 1] → [0, 1])
#   PowerLawPrior (α=2)      → reverse_bijective_transform(PowerLawTransform)

# %%
sample_transforms = [
    # SkyFrameToDetectorFrameSkyPositionTransform(trigger_time=gps, ifos=ifos),

    BoundToBound(
        name_mapping=(["M_c"], ["M_c_unit"]),
        original_lower_bound=M_c_min,
        original_upper_bound=M_c_max,
        target_lower_bound=0.0,
        target_upper_bound=1.0,
    ),

    BoundToBound(
        name_mapping=(["q"], ["q_unit"]),
        original_lower_bound=q_min,
        original_upper_bound=q_max,
        target_lower_bound=0.0,
        target_upper_bound=1.0,
    ),

    BoundToBound(
        name_mapping=(["s1_z"], ["s1_z_unit"]),
        original_lower_bound=s1_z_min,
        original_upper_bound=s1_z_max,
        target_lower_bound=0.0,
        target_upper_bound=1.0,
    ),

    BoundToBound(
        name_mapping=(["s2_z"], ["s2_z_unit"]),
        original_lower_bound=s2_z_min,
        original_upper_bound=s2_z_max,
        target_lower_bound=0.0,
        target_upper_bound=1.0,
    ),
    #reverse_bijective_transform(GaussianQuantileTransform(name_mapping=(["d_L_unit"], ["d_L"]), mu=dL_mu, sigma=dL_sigma)),
    reverse_bijective_transform(GaussianQuantileTransform(name_mapping=(["iota_unit"], ["iota"]), mu=iota_mu, sigma=iota_sigma)),
    # CosineTransform(name_mapping=(["iota"], ["cos_iota"])),

    # BoundToBound(
    #     name_mapping=(["cos_iota"], ["cos_iota_unit"]),
    #     original_lower_bound=-1.0,
    #     original_upper_bound=1.0,
    #     target_lower_bound=0.0,
    #     target_upper_bound=1.0,
    # ),

    reverse_bijective_transform(
        PowerLawTransform(
            name_mapping=(["d_L_unit"], ["d_L"]),
            xmin=d_L_min,
            xmax=d_L_max,
            alpha=2.0,
        )
    ),

    # BoundToBound(
    #     name_mapping=(["t_det"], ["t_det_unit"]),
    #     original_lower_bound=t_det_min,
    #     original_upper_bound=t_det_max,
    #     target_lower_bound=0.0,
    #     target_upper_bound=1.0,

    # ),
    #
    BoundToBound(name_mapping=(["t_c"], ["t_c_unit"]),
                 original_lower_bound=t_c_min,
                 original_upper_bound=t_c_max,
                 target_lower_bound=0.0,
                 target_upper_bound=1.0),
    BoundToBound(
        name_mapping=(["psi"], ["psi_unit"]),
        original_lower_bound=0.0,
        original_upper_bound=jnp.pi,
        target_lower_bound=0.0,
        target_upper_bound=1.0,
    ),
    BoundToBound(
        name_mapping=(["phase_c"], ["phase_c_unit"]),
        original_lower_bound=0.0,
        original_upper_bound=2*jnp.pi,
        target_lower_bound=0.0,
        target_upper_bound=1.0,
    ),


    # BoundToBound(
    #     name_mapping=(["azimuth"], ["azimuth_unit"]),
    #     original_lower_bound=0.0,
    #     original_upper_bound=2 * jnp.pi,
    #     target_lower_bound=0.0,
    #     target_upper_bound=1.0,
    # ),

    # CosineTransform(name_mapping=(["zenith"], ["cos_zenith"])),

    # BoundToBound(
    #     name_mapping=(["cos_zenith"], ["cos_zenith_unit"]),
    #     original_lower_bound=-1.0,
    #     original_upper_bound=1.0,
    #     target_lower_bound=0.0,
    #     target_upper_bound=1.0,
    # ),
]

# %%
dd2_table = np.loadtxt('DD2_mass_lambda.txt')  # header line auto-skipped (starts with #)
dd2_m_grid = jnp.array(dd2_table[:, 0])
dd2_lambda_grid = jnp.array(dd2_table[:, 1])

print("table mass range:", dd2_m_grid.min(), "-", dd2_m_grid.max())  # should print ~0.345 - 2.3845
# Out:
# table mass range: 0.3450724258 - 2.3844731798

# %%
from jimgw.core.transforms import NtoMTransform

class EOSMcEtaToLambdaTransform(NtoMTransform):
    def __init__(self, name_mapping, m_grid, lambda_grid):
        super().__init__(name_mapping)
        self.m_grid, self.lambda_grid = m_grid, lambda_grid
    def transform_func(self, x):
        Mc, eta = x["M_c"], x["eta"]
        M = Mc / eta**0.6
        root = jnp.sqrt(jnp.clip(1.0 - 4.0*eta, 0.0, None))
        m1 = 0.5*M*(1.0+root); m2 = 0.5*M*(1.0-root)
        return {
            "M_c": Mc, "eta": eta,   # pass through — don't let them get consumed
            "lambda_1": jnp.interp(m1, self.m_grid, self.lambda_grid),
            "lambda_2": jnp.interp(m2, self.m_grid, self.lambda_grid),
        }

eos_transform_dd2 = EOSMcEtaToLambdaTransform(
    (["M_c", "eta"], ["M_c", "eta", "lambda_1", "lambda_2"]),   # <- outputs include M_c, eta now
    dd2_m_grid, dd2_lambda_grid
)

# %%
test_params = {"M_c": jnp.array(1.1276930385), "eta": jnp.array(0.2485207101)}
out = eos_transform_dd2.transform_func(test_params)
print("recovered lambda_1:", out["lambda_1"], " expected: 683.0949524004478")
print("recovered lambda_2:", out["lambda_2"], " expected: 1594.4573505273822")
# Out:
# recovered lambda_1: 683.0949565302315  expected: 683.0949524004478
# recovered lambda_2: 1594.4573412772263  expected: 1594.4573505273822

# %%
import numpy as np
import matplotlib.pyplot as plt

m_check = np.linspace(np.asarray(dd2_m_grid).min(), np.asarray(dd2_m_grid).max(), 500)
lambda_check = np.interp(m_check, np.asarray(dd2_m_grid), np.asarray(dd2_lambda_grid))

plt.figure(figsize=(7,5))
plt.plot(np.asarray(dd2_m_grid), np.asarray(dd2_lambda_grid), 'o', color='navy', label="DD2 table (nodes)")
plt.plot(m_check, lambda_check, '-', color='crimson', lw=1, label="Interpolated curve")
plt.scatter([1.40, 1.20], [683.0949524004478, 1594.4573505273822],
            color='green', zorder=5, s=60, label="Injection (m1, m2)")
plt.axvspan(0.97, 1.99, color='gray', alpha=0.1, label="Prior-implied mass range")
plt.xlabel(r"$m\ [M_\odot]$"); plt.ylabel(r"$\Lambda$")
plt.legend(); plt.grid(alpha=0.3)
plt.title("DD2 M–Λ table vs interpolation")
plt.yscale("log")
plt.show()

# %%
 likelihood_transforms =[
    MassRatioToSymmetricMassRatioTransform,
    eos_transform_dd2,
    # reverse_bijective_transform(
    #     GeocentricArrivalTimeToDetectorArrivalTimeTransform(
    #         trigger_time=gps, ifo=ifos[0]
    #     )
    # ),
]

# %%
import jimgw
import jimgw.samplers
import os

print(jimgw.samplers.__path__)
# Out:
# ['/usr/local/lib/python3.12/dist-packages/jimgw/samplers']

# %%
ls -R /usr/local/lib/python3.12/dist-packages/jimgw/samplers
# Out:
# /usr/local/lib/python3.12/dist-packages/jimgw/samplers:
# base.py    config.py  __init__.py  __pycache__/
# blackjax/  flowmc.py  periodic.py
#
# /usr/local/lib/python3.12/dist-packages/jimgw/samplers/blackjax:
# _acceptance_walk_kernel.py  __init__.py  nss.py        smc.py
# _imports.py                 ns_aw.py     __pycache__/
#
# /usr/local/lib/python3.12/dist-packages/jimgw/samplers/blackjax/__pycache__:
# _acceptance_walk_kernel.cpython-312.pyc  ns_aw.cpython-312.pyc
# _imports.cpython-312.pyc                 nss.cpython-312.pyc
# __init__.cpython-312.pyc                 smc.cpython-312.pyc
#
# /usr/local/lib/python3.12/dist-packages/jimgw/samplers/__pycache__:
# base.cpython-312.pyc    flowmc.cpython-312.pyc    periodic.cpython-312.pyc
# config.cpython-312.pyc  __init__.cpython-312.pyc

# %%
# import inspect
# from jimgw.core.jim import Jim
# from jimgw.core.single_event.likelihood import TransientLikelihoodFD

# print(inspect.getsource(Jim._validate_problem))   # see exactly what "provided" is computed from
# print(inspect.signature(TransientLikelihoodFD.__init__))

# %%
 # confirm all 7 keys are actually there before building Jim

# %% [markdown]
# --- Likelihood ---

# %%
fixed_parameters = {
    #"M_c": inj_params["M_c"],
   # "d_L": inj_params["d_L"],
   # "iota": inj_params["iota"],
   # "t_c": inj_params["t_c"],
   # "psi": inj_params["psi"],
    "ra": inj_params["ra"],
    "dec": inj_params["dec"],
}

# %%
import jax.numpy as jnp
from jimgw.core.single_event.likelihood import HeterodynedTransientLikelihoodFD

def _compute_coefficients_sparse(data, h_ref, psd, freqs, f_bins, f_bins_center):
    df = freqs[1] - freqs[0]
    data_prod = jnp.array(data * h_ref.conj()) / psd
    self_prod = jnp.array(h_ref * h_ref.conj()) / psd
    n_bins = f_bins_center.shape[0]
    bin_idx = jnp.clip(jnp.searchsorted(f_bins, freqs, side="right") - 1, 0, n_bins - 1)
    bin_idx = jnp.where(freqs == f_bins[-1], n_bins - 1, bin_idx)
    freq_shift = freqs - f_bins_center[bin_idx]

    def scatter_sum(values):
        return jnp.zeros((n_bins,), dtype=values.dtype).at[bin_idx].add(values)

    A0_array = 4 * scatter_sum(data_prod) * df
    A1_array = 4 * scatter_sum(data_prod * freq_shift) * df
    B0_array = 4 * scatter_sum(self_prod) * df
    B1_array = 4 * scatter_sum(self_prod * freq_shift) * df
    return A0_array, A1_array, B0_array, B1_array

HeterodynedTransientLikelihoodFD.compute_coefficients = staticmethod(_compute_coefficients_sparse)

# %%
import jax.numpy as jnp

def _isin_sparse(element, test_elements, **kwargs):
    """Drop-in replacement for jnp.isin(element, test_elements) when `element`
    is sorted and `test_elements` is an exact subset of it (true here, since
    self.frequencies is built as the union of all detectors' frequency grids).
    O(n) memory instead of O(len(element) * len(test_elements))."""
    element = jnp.asarray(element)
    test_elements = jnp.asarray(test_elements)
    idx = jnp.searchsorted(element, test_elements)
    idx = jnp.clip(idx, 0, element.shape[0] - 1)
    return jnp.zeros(element.shape[0], dtype=bool).at[idx].set(True)

jnp.isin = _isin_sparse

# %%
likelihood_het = HeterodynedTransientLikelihoodFD(
    ifos, waveform=waveform, trigger_time=gps, f_min=fmin, f_max=fmax,
    fixed_parameters=fixed_parameters,
    reference_parameters=inj_params,   # or the posterior median, either is reasonable here
   # phase_marginalization=True,
)
# Out:
# INFO | jimgw.core.single_event.likelihood | Initializing heterodyned likelihood..
# INFO | jimgw.core.single_event.likelihood | Reference parameters provided, which are {'M_c': 1.1276930385, 'eta': 0.2485207101, 's1_z': 0.028327, 's2_z': 0.013249, 'd_L': 1200.0, 'lambda_1': 683.0949524004478, 'lambda_2': 1594.4573505273822, 't_c': -0.000236, 'phase_c': 2.0, 'iota': 2.8495, 'psi': 0.7, 'ra': 3.4396, 'dec': -0.3998}
# INFO | jimgw.core.single_event.likelihood | Constructing reference waveforms..

# %% [markdown]
# --- Sample ---

# %%
SEED = 1

jim = Jim(
    #likelihood,
    likelihood_het,
    prior,
    sample_transforms=sample_transforms,
    likelihood_transforms=likelihood_transforms,
   # periodic=["psi_unit", "azimuth_unit"],
    periodic=["psi_unit","phase_c_unit"],
    sampler_config=BlackJAXNSAWConfig(
        n_live=500,
        n_delete_frac=0.25,
        n_target=80,
    ),
)
# Out:
# INFO | jimgw.core.jim | Using sample transforms.

# %%
jim._rng_key, jim._sampler_key = jax.random.split(jax.random.key(SEED), 2)

# %%
print("SEED =", SEED)
print("rng key:", jim._rng_key)
print("sampler key:", jim._sampler_key)

# If you want to see the raw uint32 values:
print("rng key data:", jax.random.key_data(jim._rng_key))
print("sampler key data:", jax.random.key_data(jim._sampler_key))
# Out:
# SEED = 1
# rng key: Array((), dtype=key<fry>) overlaying:
# [ 507451445 1853169794]
# sampler key: Array((), dtype=key<fry>) overlaying:
# [1948878966 4237131848]
# rng key data: [ 507451445 1853169794]
# sampler key data: [1948878966 4237131848]

# %% [markdown]
# #Sample

# %%
start_time = time.time()
jim.sample()
end_time = time.time()
print(f"Sampling took {(end_time - start_time) / 60:.2f} mins")
# Out:
# Sampling took 11.37 mins

# %%
inj_full = dict(inj_params)
logL_at_injection = likelihood_het.evaluate(inj_full)
print("logL at injection:", logL_at_injection)

chains = jim.get_samples()
print("max logL sampler:", np.max(chains["log_likelihood"]))
# Out:
# logL at injection: 6242.371255615505
# max logL sampler: 6242.256318971269

# %%
q_c = np.asarray(chains["q"]); eta_c = q_c/(1+q_c)**2
Mc_c = np.asarray(chains["M_c"]); M_c_tot = Mc_c/eta_c**0.6
root_c = np.sqrt(np.clip(1-4*eta_c, 0, None))
m1_c = 0.5*M_c_tot*(1+root_c); m2_c = 0.5*M_c_tot*(1-root_c)
chains["lambda_1"] = np.interp(m1_c, np.asarray(dd2_m_grid), np.asarray(dd2_lambda_grid))
chains["lambda_2"] = np.interp(m2_c, np.asarray(dd2_m_grid), np.asarray(dd2_lambda_grid))

# %%
import os
import numpy as np
import jax

# -----------------------------
# Samples
# -----------------------------
samples = jim.get_samples()
samples = {k: np.asarray(v) for k, v in samples.items()}

# -----------------------------
# Diagnostics
# -----------------------------
diagnostics = jim.get_diagnostics()

# -----------------------------
# RNG keys
# -----------------------------
rng_key = jax.random.key_data(jim._rng_key)
sampler_key = jax.random.key_data(jim._sampler_key)

# -----------------------------
# Automatic filename
# -----------------------------
filename = (
    f"m1=1.40_m2=1.20_dL=1200_Lambda_DD2_correct_duration=8192_IMRPHENOMD_ET3+2CE_GN_Het_gauss_dl_iota_Nested_fmax=2048_nlive=500_phic_Injection_NSAW_"
    f"rng_{rng_key[0]}_{rng_key[1]}_"
    f"logZ_{diagnostics['log_Z']:.2f}.npz"
)

counter = 1
base = filename[:-4]
while os.path.exists(filename):
    filename = f"{base}_{counter}.npz"
    counter += 1

# -----------------------------
# Save everything
# -----------------------------
np.savez_compressed(
    filename,
    **samples,
    rng_key=rng_key,
    sampler_key=sampler_key,
    logZ=diagnostics["log_Z"],
    logZ_error=diagnostics["log_Z_error"],
    n_likelihood_evaluations=diagnostics["n_likelihood_evaluations"],
)

print(f"Saved to: {filename}")
# Out:
# Saved to: m1=1.40_m2=1.20_dL=1200_Lambda_DD2_correct_duration=8192_IMRPHENOMD_ET3+2CE_GN_Het_gauss_dl_iota_Nested_fmax=2048_nlive=500_phic_Injection_NSAW_rng_3704974950_1863054868_logZ_6211.30.npz

# %%
print("logZ:", diagnostics["log_Z"], diagnostics["log_Z_error"])
print("max logL:", np.max(samples["log_likelihood"]))
print("median logL:", np.median(samples["log_likelihood"]))
# Out:
# logZ: 6211.299130348681 0.2567334435635623
# max logL: 6242.256318971269
# median logL: 6239.750879441237

# %%
print(jim.__dict__.keys())
# Out:
# dict_keys(['likelihood', 'prior', 'sample_transforms', 'likelihood_transforms', 'parameter_names', '_log_prior_fn', '_log_likelihood_fn', '_log_posterior_fn', '_rng_key', '_sampler_key', '_sampler_config', 'sampler'])

# %%
print(jim._rng_key)
print(jim._sampler_key)
# Out:
# Array((), dtype=key<fry>) overlaying:
# [3704974950 1863054868]
# Array((), dtype=key<fry>) overlaying:
# [1948878966 4237131848]

# %% [markdown]
# --- Results ---

# %%
diagnostics = jim.get_diagnostics()
print(f"log Z = {diagnostics['log_Z']:.2f} ± {diagnostics['log_Z_error']:.2f}")
print(f"Likelihood evaluations: {diagnostics['n_likelihood_evaluations']:,}")
# Out:
# log Z = 6211.30 ± 0.24
# Likelihood evaluations: 19,408,714

# %%
import numpy as np
import matplotlib.pyplot as plt
import corner

def eta_to_q(eta):
    """Invert eta = q/(1+q)^2 for q in (0,1]."""
    return ((1 - 2*eta) - np.sqrt(1 - 4*eta)) / (2*eta)

q_inj = eta_to_q(inj_params["eta"])
print("q_inj (from injected eta):", q_inj)


params = ["M_c","q", "s1_z", "s2_z","d_L","iota","phase_c","psi","t_c","lambda_1","lambda_2"]
labels = [
   r"M_c", r"$q$", r"$s_{1z}$", r"$s_{2z}$",r"$d_L$",r"$\iota$",r"$\phi_c$",r"$\psi$",r"$t_c$",r"$\Lambda_1$",r"$\Lambda_2$"

]
truths = [
    inj_params["M_c"],
    q_inj,
    inj_params["s1_z"],
    inj_params["s2_z"],
    inj_params["d_L"],
    inj_params["iota"],
    inj_params["phase_c"],
    inj_params["psi"],
    inj_params["t_c"],
    inj_params["lambda_1"],
    inj_params["lambda_2"],

]

samples = np.vstack([np.asarray(chains[p]) for p in params]).T

level_1sigma = 0.39346934
level_2sigma = 0.86466472
fig = corner.corner(
    samples,
    labels=labels,
    truths=truths,
    truth_color="crimson",
    levels=(level_1sigma, level_2sigma),
    plot_datapoints=False,
    plot_density=False,
    fill_contours=True,
    color="navy",
    hist_kwargs={"color": "navy", "linewidth": 1.5},
    truth_kwargs={"color": "crimson", "linewidth": 1.8, "linestyle": "--"},
    show_titles=True,
    title_fmt=".4g",
    title_kwargs={"fontsize": 11},
    smooth=1.0,
    smooth1d=1.0,
    bins=40,
)
plt.savefig("dL=1200_lambda_DD2_correct_duration=8192_IMRPHENOMD_ET3+2CE_GN_Het__gauss_dl_iota_nlive=500_phic_corner_injection_1sigma_2sigma.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# q_inj (from injected eta): 0.8571428589734689

# %%
truths
# Out:
# [1.1276930385,
#  np.float64(0.8571428589734689),
#  0.028327,
#  0.013249,
#  1200.0,
#  2.8495,
#  2.0,
#  0.7,
#  -0.000236,
#  683.0949524004478,
#  1594.4573505273822]

# %%
import numpy as np

params = ["M_c", "q", "s1_z", "s2_z","d_L","iota","phase_c","psi","t_c"]

for p in params:
    x = np.asarray(chains[p])
    median = np.median(x)
    std = np.std(x, ddof=1)   # sample standard deviation
    print(f"{p:8s} median = {median:.6f}, std = {std:.6f}")
# Out:
# M_c      median = 1.127691, std = 0.000004
# q        median = 0.887884, std = 0.050295
# s1_z     median = 0.023326, std = 0.016227
# s2_z     median = 0.017279, std = 0.018115
# d_L      median = 1200.730769, std = 15.609391
# iota     median = 2.848439, std = 0.030542
# phase_c  median = 3.290265, std = 1.794602
# psi      median = 1.532968, std = 0.900827
# t_c      median = -0.000225, std = 0.000041

# %%
for p, inj in [
    ("M_c", inj_params["M_c"]),
    ("q", q_inj),
    ("s1_z", inj_params["s1_z"]),
    ("s2_z", inj_params["s2_z"]),
    ("d_L", inj_params["d_L"]),
    ("iota", inj_params["iota"]),
    ("phase_c", inj_params["phase_c"]),
    ("psi", inj_params["psi"]),
    ("t_c", inj_params["t_c"]),
]:
    x = np.asarray(chains[p])
    perc = 100 * np.mean(x < inj)
    print(f"{p:6s}: injected value at {perc:.1f} percentile")
# Out:
# M_c   : injected value at 71.2 percentile
# q     : injected value at 27.1 percentile
# s1_z  : injected value at 59.6 percentile
# s2_z  : injected value at 42.8 percentile
# d_L   : injected value at 48.4 percentile
# iota  : injected value at 51.1 percentile
# phase_c: injected value at 29.3 percentile
# psi   : injected value at 21.9 percentile
# t_c   : injected value at 38.3 percentile

# %%
frequencies = ifos[0].data.frequencies

# %%
h_inj = waveform(frequencies, inj_params)   # inj_params already has 'eta' directly

median_params = dict(fixed_parameters)   # everything currently fixed, physical values

if "M_c" in chains:
    median_params["M_c"] = float(np.median(chains["M_c"]))
if "q" in chains:
    q_med = float(np.median(chains["q"]))
    median_params["eta"] = q_med / (1 + q_med) ** 2
if "s1_z" in chains:
    median_params["s1_z"] = float(np.median(chains["s1_z"]))
if "s2_z" in chains:
    median_params["s2_z"] = float(np.median(chains["s2_z"]))
if "d_L" in chains:
    median_params["d_L"] = float(np.median(chains["d_L"]))
if "iota" in chains:
    median_params["iota"] = float(np.median(chains["iota"]))
if "phase_c" in chains:
    median_params["phase_c"] = float(np.median(chains["phase_c"]))
else:
    median_params["phase_c"] = 0.0
if "lambda_1" in chains: median_params["lambda_1"] = float(np.median(chains["lambda_1"]))
if "lambda_2" in chains: median_params["lambda_2"] = float(np.median(chains["lambda_2"]))

h_med = waveform(frequencies, median_params)

# %%
plt.figure(figsize=(7,5))

plt.loglog(frequencies, np.abs(h_inj["p"]), label="Injection plus")
plt.loglog(frequencies, np.abs(h_med["p"]), "--", label="Posterior median plus")

plt.xlabel("Frequency [Hz]")
plt.ylabel(r"$|h_+(f)|$")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/gwpy/plot/axes.py:201: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   super().draw(renderer)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(7,5))

plt.loglog(frequencies, np.abs(h_inj["c"]), label="Injection cross")
plt.loglog(frequencies, np.abs(h_med["c"]), "--", label="Posterior median cross")

plt.xlabel("Frequency [Hz]")
plt.ylabel(r"$|h_\times(f)|$")
plt.legend()
plt.grid(alpha=0.3)
plt.show()

# %%
psi_inj = inj_params["psi"]
phase_c_inj = inj_params["phase_c"]
phase_c_alt = phase_c_inj + np.pi
psi_tol = 0.1  # radians
mask = np.abs(np.asarray(chains["psi"]) - psi_inj) < psi_tol
phase_c_near_psi_inj = np.asarray(chains["phase_c"])[mask]

plt.hist(phase_c_near_psi_inj, bins=40)
plt.axvline(phase_c_inj, color="r", label="inj")
plt.axvline(phase_c_alt, color="g", linestyle="--", label="inj + π (mod 2π)")
plt.legend()
plt.title(f"phase_c conditioned on psi near injection (n={mask.sum()})")
plt.show()

# %%
# import jax
# import jax.numpy as jnp
# import numpy as np

# samples = chains
# samples = {k: np.asarray(v) for k, v in samples.items()}
# n_check = 50
# idx = np.random.choice(len(samples["M_c"]), n_check, replace=False)

# def mass_ratio_to_eta(q):
#     return q / (1 + q) ** 2

# p_batch = {k: jnp.asarray(v[idx]) for k, v in samples.items() if k not in ("log_likelihood", "log_prior", "q")}
# p_batch["eta"] = mass_ratio_to_eta(jnp.asarray(samples["q"][idx]))
# for k, v in fixed_parameters.items():
#     p_batch[k] = jnp.full(n_check, v)  # broadcast fixed params to match batch dim

# eval_full_jit = jax.jit(jax.vmap(likelihood.evaluate))
# eval_het_jit = jax.jit(jax.vmap(likelihood_het.evaluate))

# logL_full = eval_full_jit(p_batch)
# logL_het = eval_het_jit(p_batch)

# diffs = np.asarray(logL_full) - np.asarray(logL_het)
# print("max |diff|:", np.abs(diffs).max(), " mean:", diffs.mean(), " std:", diffs.std())

# %%
import jimgw.core.prior as prior_module
print([x for x in dir(prior_module) if any(s in x for s in ("Gauss", "Normal", "Truncated"))])
# Out:
# ['GaussianPrior', 'StandardNormalDistribution']

# %%
import inspect
from jimgw.core.prior import GaussianPrior, StandardNormalDistribution

print(inspect.getsource(GaussianPrior))
print("=" * 80)
print(inspect.getsource(StandardNormalDistribution))
# Out:
# @jaxtyped(typechecker=typechecker)
# class GaussianPrior(SequentialTransformPrior):
#     """Gaussian (normal) prior with specified mean and standard deviation.
#
#     Attributes:
#         mu: Mean of the distribution.
#         sigma: Standard deviation of the distribution.
#     """
#
#     mu: float
#     sigma: float
#
#     def __repr__(self):
#         return f"GaussianPrior(mu={self.mu}, sigma={self.sigma}, parameter_names={self.parameter_names})"
#
#     def __init__(
#         self,
#         mu: float,
#         sigma: float,
#         parameter_names: list[str],
#     ):
#         """
#         Args:
#             mu: Mean of the distribution.
#             sigma: Standard deviation of the distribution.
#             parameter_names: List with a single parameter name.
#         """
#         assert len(parameter_names) == 1, "GaussianPrior needs to be 1D distributions"
#         assert sigma > 0, "sigma must be positive"
#         self.mu = mu
#         self.sigma = sigma
#         super().__init__(
#             [StandardNormalDistribution([f"{parameter_names[0]}_base"])],
#             [
#                 ScaleTransform(
#                     (
#                         [f"{parameter_names[0]}_base"],
#                         [f"{parameter_names[0]}-({mu})"],
#                     ),
#                     sigma,
#                 ),
#                 OffsetTransform(
#                     ([f"{parameter_names[0]}-({mu})"], parameter_names),
#                     mu,
#                 ),
#             ],
#         )
#
# ================================================================================
# @jaxtyped(typechecker=typechecker)
# class StandardNormalDistribution(Prior):
#     """One-dimensional standard normal (Gaussian) distribution prior."""
#
#     @property
#     def is_normalized(self) -> bool:
#         return True
#
#     def __repr__(self):
#         return f"StandardNormalDistribution(parameter_names={self.parameter_names})"
#
#     def __init__(self, parameter_names: list[str]):
#         super().__init__(parameter_names)
#         assert self.n_dims == 1, (
#             "StandardNormalDistribution needs to be 1D distributions"
#         )
#
#     def sample(
#         self, rng_key: Key, n_samples: int
#     ) -> dict[str, Float[Array, " n_samples"]]:
#         """Sample from a standard normal distribution.
#
#         Args:
#             rng_key: JAX PRNG key.
#             n_samples: Number of samples to draw.
#
#         Returns:
#             Dict mapping parameter name to samples of shape ``(n_samples,)``.
#         """
#         samples = jax.random.normal(rng_key, (n_samples,))
#         return self.add_name(samples[None])
#
#     def log_prob(self, z: dict[str, Float]) -> FloatScalar:
#         variable = z[self.parameter_names[0]]
#         return -0.5 * (variable**2 + jnp.log(2 * jnp.pi))
